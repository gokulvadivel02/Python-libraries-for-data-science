# %%
import pandas as pd

# %%
# reads csv file
df = pd.read_csv('players_20.csv')
# set index
df.set_index('short_name', inplace=True)
# select column
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %%
df.head(3)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain

# %%
# update L. Messi height
df.loc['L. Messi', 'weight_kg'] = 100
df.head(2)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170        100   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
# set everyones height as 190
df.loc[:,'height_cm'] = 190
df.tail(3)
# Out:
#              long_name   age         dob  height_cm  weight_kg nationality  \
# short_name
# Zhang Wei           张威  19.0  2000-05-16      190.0       75.0    China PR
# Wang Haijian       汪海健  18.0  2000-08-02      190.0       74.0    China PR
# Pan Ximing         NaN   NaN         NaN      190.0        NaN         NaN
#
#                                        club
# short_name
# Zhang Wei            Hebei China Fortune FC
# Wang Haijian  Shanghai Greenland Shenhua FC
# Pan Ximing                              NaN

# %% [markdown]
# # Set value to entire row

# %%
#get the entire row 
df.iloc[-1]
df.iloc[-1,:]
# Out:
# long_name                         潘喜明
# age                                26
# dob                        1993-01-11
# height_cm                         190
# weight_kg                          78
# nationality                  China PR
# club           Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
 #setting nan as a value for a particular rows entire column
df.iloc[-1,:] = np.nan
df.tail(3)
# Out:
#              long_name   age         dob  height_cm  weight_kg nationality  \
# short_name
# Zhang Wei           张威  19.0  2000-05-16      190.0       75.0    China PR
# Wang Haijian       汪海健  18.0  2000-08-02      190.0       74.0    China PR
# Pan Ximing         NaN   NaN         NaN        NaN        NaN         NaN
#
#                                        club
# short_name
# Zhang Wei            Hebei China Fortune FC
# Wang Haijian  Shanghai Greenland Shenhua FC
# Pan Ximing                              NaN

# %% [markdown]
# # Set value to Multiple cells

# %%
df.loc[['L. Messi', 'Cristiano Ronaldo'],['height_cm','weight_kg' ]] = 200
df.head(3)
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi               200.0      200.0   Argentina         FC Barcelona
# Cristiano Ronaldo      200.0      200.0    Portugal             Juventus
# Neymar Jr              190.0       68.0      Brazil  Paris Saint-Germain

# %% [markdown]
# # Set value for rows matching a condition

# %%
# set value for rows matching a condition
columns = ['age', 'dob', 'height_cm', 'weight_kg']

df.loc[df['height_cm']>180 ,columns ] = 0
df
# Out:
#                                              long_name  age  dob  height_cm  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  0.0    0        0.0
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  0.0    0        0.0
# Neymar Jr                Neymar da Silva Santos Junior  0.0    0        0.0
# J. Oblak                                     Jan Oblak  0.0    0        0.0
# E. Hazard                                  Eden Hazard  0.0    0        0.0
# ...                                                ...  ...  ...        ...
# Shao Shuai                                          邵帅  0.0    0        0.0
# Xiao Mingjie                              Mingjie Xiao  0.0    0        0.0
# Zhang Wei                                           张威  0.0    0        0.0
# Wang Haijian                                       汪海健  0.0    0        0.0
# Pan Ximing                                         NaN  NaN  NaN        NaN
#
#                    weight_kg nationality                           club
# short_name
# L. Messi                 0.0   Argentina                   FC Barcelona
# Cristiano Ronaldo        0.0    Portugal                       Juventus
# Neymar Jr                0.0      Brazil            Paris Saint-Germain
# J. Oblak                 0.0    Slovenia                Atlético Madrid
# E. Hazard                0.0     Belgium                    Real Madrid
# ...                      ...         ...                            ...
# Shao Shuai               0.0    China PR               Beijing Renhe FC
# Xiao Mingjie             0.0    China PR               Shanghai SIPG FC
# Zhang Wei                0.0    China PR         Hebei China Fortune FC
# Wang Haijian             0.0    China PR  Shanghai Greenland Shenhua FC
# Pan Ximing               NaN         NaN                            NaN
#
# [18278 rows x 7 columns]
