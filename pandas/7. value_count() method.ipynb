# %%
import pandas as pd
df = pd.read_csv('organizations.csv')
df.head()
# Out:
#    Index  Organization Id           Name                       Website  \
# 0      1  E84A904909dF528     Liu-Hoover   http://www.day-hartman.org/
# 1      2  AAC4f9aBF86EAeF  Orr-Armstrong      https://www.chapman.net/
# 2      3  ad2eb3C8C24DB87      Gill-Lamb               http://lin.com/
# 3      4  D76BB12E5eE165B    Bauer-Weiss  https://gillespie-stout.com/
# 4      5  2F31EddF2Db9aAE    Love-Palmer           https://kramer.com/
#
#                     Country                                   Description  \
# 0            Western Sahara  Ergonomic zero administration knowledge user
# 1                   Algeria        Ergonomic radical budgetary management
# 2             Cote d'Ivoire      Programmable intermediate conglomeration
# 3  United States of America              Synergistic maximized definition
# 4                   Denmark                Optimized optimizing moderator
#
#    Founded               Industry  Number of employees
# ...

# %% [markdown]
# 1. Value Count

# %%
# count specfic elements 

# len function
len(df['Number of employees'])

# . count() method
df['Number of employees'].count()
# Out:
# np.int64(1000)

# %%
# counting elements based on different catagory
df['Industry'].value_counts()
# Out:
# Industry
# Library                             18
# Maritime                            15
# Furniture                           14
# Medical Equipment                   13
# Oil / Energy / Solar / Greentech    13
#                                     ..
# Civil Engineering                    2
# Non - Profit / Volunteering          2
# Consumer Goods                       2
# Semiconductors                       1
# Tobacco                              1
# Name: count, Length: 147, dtype: int64

# %%
# return relative frequency (divide all values by the sum of values)
df['Industry'].value_counts(normalize=True)
# Out:
# Industry
# Library                             0.018
# Maritime                            0.015
# Furniture                           0.014
# Medical Equipment                   0.013
# Oil / Energy / Solar / Greentech    0.013
#                                     ...
# Civil Engineering                   0.002
# Non - Profit / Volunteering         0.002
# Consumer Goods                      0.002
# Semiconductors                      0.001
# Tobacco                             0.001
# Name: proportion, Length: 147, dtype: float64
