# %%
# import pandas
import pandas as pd

# %%
df = pd.read_csv('bestsellers with categories.csv')

# %% [markdown]
# # Create a DataFrame

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
# get access to the shape attribute
df.shape
# Out:
# (550, 7)

# %%
# find the data types of each column
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Display a DataFrame

# %%
# show first 5 rows in a dataframe 
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# describe basic statistics of the dataframe (mean, std, min, max) 
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# # Add a new Column with an array

# %%
#   create a column named 'Critic Rating' that should have random integer numbers between 1 and 4
# 1. import numpy and create 550 random integer numbers between 1 and 4
import numpy as np
cr_int = np.random.randint(1,4, size=10) # generate random integer num
cr = (np.random.rand(len(df))*4).round(2)

# 2. add new 'Critic Rating' column to dataframe using the random numbers created
df['Critic Rating'] = cr

# %%
df.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre  Critic Rating
# 545          4.9     9413      8  2019      Fiction           0.92
# 546          4.7    14331      8  2016  Non Fiction           3.66
# 547          4.7    14331      8  2017  Non Fiction           2.70
# 548          4.7    14331      8  2018  Non Fiction           3.38
# 549          4.7    14331      8  2019  Non Fiction           3.09

# %% [markdown]
# # Basic Attributes, Methods and Functions

# %%
# get access to the columns attribute
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'Critic Rating'],
#       dtype='object')

# %% [markdown]
# ## Selecting Two or More Columns from a Dataframe

# %%
# move the new 'Critic Rating' column between the columns "User Rating" and "Reviews" Then update the dataframe
df[['Name', 'Author', 'User Rating', 'Critic Rating', 'Reviews', 'Price', 'Year', 'Genre'
       ]]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic Rating  Reviews  Price  \
# 0                    JJ Smith          4.7           2.11    17350      8
# 1                Stephen King          4.6           1.53     2052     22
# 2          Jordan B. Peterson          4.7           0.25    18979     15
# 3               George Orwell          4.7           2.13    21424      6
# 4    National Geographic Kids          4.8           3.88     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9           0.92     9413      8
# 546               Jen Sincero          4.7           3.66    14331      8
# 547               Jen Sincero          4.7           2.70    14331      8
# 548               Jen Sincero          4.7           3.38    14331      8
# 549               Jen Sincero          4.7           3.09    14331      8
#
#      Year        Genre
# 0    2016  Non Fiction
# 1    2011      Fiction
# 2    2018  Non Fiction
# 3    2017      Fiction
# 4    2019  Non Fiction
# ..    ...          ...
# 545  2019      Fiction
# 546  2016  Non Fiction
# 547  2017  Non Fiction
# 548  2018  Non Fiction
# 549  2019  Non Fiction
#
# [550 rows x 8 columns]

# %% [markdown]
# # Operations on Dataframes

# %%
# create a column named "Average Rating" by using the following formula: Average Rating = (User Rating + Critic Rating)/2
df['Average Rating'] = (df['User Rating'] +df['Critic Rating'])/2

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating  Average Rating
# 0           2.11           3.405
# 1           1.53           3.065
# 2           0.25           2.475
# 3           2.13           3.415
# 4           3.88           4.340

# %%
# use the round function to round the values of the dataframe to 1 decimal and update the dataframe
df.round(1).head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating  Average Rating
# 0            2.1             3.4
# 1            1.5             3.1
# 2            0.2             2.5
# 3            2.1             3.4
# 4            3.9             4.3

# %% [markdown]
# # Value Counts

# %%
# count elements in "Genre" column by category and return the relative frequency 
df.value_counts('Genre') # show no of diff values
df["Genre"].value_counts(normalize=True)
# Out:
# Genre
# Non Fiction    0.563636
# Fiction        0.436364
# Name: proportion, dtype: float64

# %% [markdown]
# # Rename Columns

# %%
# rename columns "User Rating," "Critic Rating" and "Average Rating" to "UR," "CR" and "AR" then update the dataframe with the inplace paraneter
df.rename(columns={'User Rating':'ur','Critic Rating':'cr',
                   'Average Rating':'ar'}, inplace=True)

# %% [markdown]
# # sort

# %%
df.sort_values(['ar','cr'], ascending=False)
# Out:
#                                                   Name                 Author  \
# 477                        The Very Hungry Caterpillar             Eric Carle
# 153  Harry Potter and the Chamber of Secrets: The I...           J.K. Rowling
# 488                   The Wonderful Things You Will Be  Emily Winfield Martin
# 476                        The Very Hungry Caterpillar             Eric Carle
# 203  Kitchen Confidential Updated Edition: Adventur...       Anthony Bourdain
# ..                                                 ...                    ...
# 22                                           Allegiant          Veronica Roth
# 182                                            Inferno              Dan Brown
# 307                                StrengthsFinder 2.0                 Gallup
# 132                         Go Set a Watchman: A Novel             Harper Lee
# 353                                 The Casual Vacancy           J.K. Rowling
#
#       ur  Reviews  Price  Year        Genre    cr     ar
# 477  4.9    19546      5  2014      Fiction  3.97  4.435
# 153  4.9    19622     30  2016      Fiction  3.95  4.425
# 488  4.9     8842     10  2018      Fiction  3.94  4.420
# 476  4.9    19546      5  2013      Fiction  3.90  4.400
# 203  4.8     2507      8  2018  Non Fiction  3.96  4.380
# ..   ...      ...    ...   ...          ...   ...    ...
# 22   3.9     6310     13  2013      Fiction  0.33  2.115
# 182  4.1    29651     14  2013      Fiction  0.01  2.055
# 307  4.0     5069     17  2012  Non Fiction  0.07  2.035
# 132  3.6    14982     19  2015      Fiction  0.09  1.845
# 353  3.3     9372     12  2012      Fiction  0.12  1.710
#
# [550 rows x 9 columns]
